# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/IEEE ZSB Database.xlsx - Form Responses 1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 16 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Unnamed: 0                                                0 non-null      float64
#  1   Unnamed: 1                                                0 non-null      float64
#  2   Committee\Chapter                                         296 non-null    object
#  3   Unnamed: 3                                                0 non-null      float64
#  4   Unnamed: 4                                                0 non-null      float64
#  5   Unnamed: 5                                                0 non-null      float64
#  6   Unnamed: 6                                                0 non-null      float64
#  7   Unnamed: 7                                                0 non-null      float64
# ...

# %%
df = df.dropna(axis = 1, how = 'all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 7 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Committee\Chapter                                         296 non-null    object
#  1   Faculty                                                   296 non-null    object
#  2   Grade                                                     296 non-null    object
#  3   City                                                      296 non-null    object
#  4   Date of birth                                             296 non-null    object
#  5   If you're part of two teams, what's of your second team?  60 non-null     object
#  6   Expected year of graduation                               296 non-null    object
# dtypes: object(7)
# memory usage: 16.3+ KB

# %%
df.head(20)
# Out:
#    Committee\Chapter                                           Faculty  \
# 0        Ambassadors                                       Engineering
# 1        Ambassadors                                      Engineering
# 2        Ambassadors  Faculty Of Commerce Credit Hours English program
# 3        Ambassadors                                       Engineering
# 4        Ambassadors                       Faculty of Arts Sociology *
# 5        Ambassadors       computer and information zagazig university
# 6        Ambassadors                                 Arts of sociology
# 7        Ambassadors                           Faculty of Agriculture
# 8        Ambassadors                                      Engineering
# 9                 BD                                       Engineering
# 10                BD                      Faculty of engineering (ECE)
# 11                BD                                      Engineering
# ...

# %%
df['Expected year of graduation'] = df['Expected year of graduation'].astype('string')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 7 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Committee\Chapter                                         296 non-null    object
#  1   Faculty                                                   296 non-null    object
#  2   Grade                                                     296 non-null    object
#  3   City                                                      296 non-null    object
#  4   Date of birth                                             296 non-null    object
#  5   If you're part of two teams, what's of your second team?  60 non-null     object
#  6   Expected year of graduation                               296 non-null    string
# dtypes: object(6), string(1)
# memory usage: 16.3+ KB

# %%
df['Expected year of graduation'].replace({'In shaa Allah 2025':'2025',
                                           'Engineering':'2025',
                                           'very good':'2024',
                                           '2025-2026':'2026',
                                           '2025/2026':'2026'},inplace =True)
df['City'].replace({'ديرب نجم':'Diarb Negm'})
# Out:
# 0      10th of ramadan city
# 1                    Hehia
# 2                   Zagazig
# 3      10th of Ramadan city
# 4                  Belbies
#                ...
# 291                  Zefta
# 292                Zagazig
# 293                 Belbais
# 294                  fakous
# 295                 Zagazig
# Name: City, Length: 296, dtype: object

# %%
df.rename(columns={"If you're part of two teams, what's of your second team?":"second team"})
# Out:
#     Committee\Chapter                                           Faculty  \
# 0         Ambassadors                                       Engineering
# 1         Ambassadors                                      Engineering
# 2         Ambassadors  Faculty Of Commerce Credit Hours English program
# 3         Ambassadors                                       Engineering
# 4         Ambassadors                       Faculty of Arts Sociology *
# ..                ...                                               ...
# 291               WIE                                      Engineering
# 292               WIE                                      Engineering
# 293               WIE                                      Engineering
# 294               WIE                                      engineering
# 295                CS                                       Engineering
#
#                Grade                  City Date of birth  second team  \
# ...

# %%
df["If you're part of two teams, what's of your second team?"].fillna('No',inplace = True)
df
# Out:
#     Committee\Chapter                                           Faculty  \
# 0         Ambassadors                                       Engineering
# 1         Ambassadors                                      Engineering
# 2         Ambassadors  Faculty Of Commerce Credit Hours English program
# 3         Ambassadors                                       Engineering
# 4         Ambassadors                       Faculty of Arts Sociology *
# ..                ...                                               ...
# 291               WIE                                      Engineering
# 292               WIE                                      Engineering
# 293               WIE                                      Engineering
# 294               WIE                                      engineering
# 295                CS                                       Engineering
#
#                Grade                  City Date of birth   \
# ...

# %%
df['Expected year of graduation'].value_counts()
# Out:
# Expected year of graduation
# 2025            165
# 2026             81
# 2024             33
# 2027             11
# 2028              3
# Graduated         1
# 2023              1
# Engineering       1
# Name: count, dtype: Int64

# %%
df.head(20)
# Out:
#    Committee\Chapter                                           Faculty  \
# 0        Ambassadors                                       Engineering
# 1        Ambassadors                                      Engineering
# 2        Ambassadors  Faculty Of Commerce Credit Hours English program
# 3        Ambassadors                                       Engineering
# 4        Ambassadors                       Faculty of Arts Sociology *
# 5        Ambassadors       computer and information zagazig university
# 6        Ambassadors                                 Arts of sociology
# 7        Ambassadors                           Faculty of Agriculture
# 8        Ambassadors                                      Engineering
# 9                 BD                                       Engineering
# 10                BD                      Faculty of engineering (ECE)
# 11                BD                                      Engineering
# ...

# %%
  count= df['Expected year of graduation'].value_counts()
# Out:
# Expected year of graduation
# 2025            165
# 2026             81
# 2024             33
# 2027             11
# 2028              3
# Graduated         1
# 2023              1
# Engineering       1
# Name: count, dtype: Int64

# %%
plt.hist(df['Committee\Chapter'],bins =10,edgecolor= 'black')
plt.title('Committee')
plt.tight_layout()

# %%
replace_dict = {
    'engineering': 'Engineering',
    'Faculty of engineering': 'Engineering',
    'Faculty of Engineering Faculty': 'Engineering',
    'Faculty of Engineering': 'Engineering'
}
df['Faculty'] = df['Faculty'].replace( replace_dict)
df.head(20)
# Out:
#    Committee\Chapter Faculty            Grade                  City  \
# 0        Ambassadors    None  2nd mecha power  10th of ramadan city
# 1        Ambassadors    None         3rd year                Hehia
# 2        Ambassadors    None         3rd year               Zagazig
# 3        Ambassadors    None         3rd year  10th of Ramadan city
# 4        Ambassadors    None         4th year              Belbies
# 5        Ambassadors    None         2nd year               Zagazig
# 6        Ambassadors    None         3rd year           El-sharkia
# 7        Ambassadors    None         3rd year              Zagazig
# 8        Ambassadors    None         3rd year                 hahia
# 9                 BD    None         4th year               Zagazig
# 10                BD    None         4th year              Zagazig
# 11                BD    None         4th year              Zagazig
# 12                BD    None         5th year               Zagazig
# ...
